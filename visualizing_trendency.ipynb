# %%
import torch 
import numpy as np 
import matplotlib.pyplot as plt

# %%
list_c4synth_perplexity = [21.12, 18.42, 19.01] 
list_c4_perplexity = [50.35, 44.17, 46.2] 
list_pg19_perplexity = [76.32, 123.56, 108.89]

# %%
checkpoint_list = [1000, 2000, 3000] 
plt.plot(checkpoint_list, list_c4synth_perplexity, label='c4synth', marker='o') 
plt.plot(checkpoint_list, list_c4_perplexity, label='c4', marker = "o") 
plt.plot(checkpoint_list, list_pg19_perplexity, label='pg19', marker = "o") 
plt.xlabel("step count") 
plt.ylabel("perplexity") 
plt.grid() 
plt.legend() 
plt.show()

# %%
ce_loss_c4synth = [3.05, 2.91, 2.94] 
ce_loss_c4 = [3.91, 3.78, 3.83] 
ce_loss_pg19 = [4.81, 4.69, 4.74] 
plt.plot(checkpoint_list, ce_loss_c4synth, label='c4synth', marker='o') 
plt.plot(checkpoint_list, ce_loss_c4, label='c4', marker = "o") 
plt.plot(checkpoint_list, ce_loss_pg19, label='pg19', marker = "o") 
plt.xlabel("step count") 
plt.ylabel("cross entropy loss") 
plt.grid() 
plt.legend() 
plt.show()

# %%
# kernelsize7_position = [0.767, 0.756, 0.702, 0.685, 0.704, 0.697, 0.702] 
# kernelsize2_position = [0.801, 0.736] 
# kernelsize1_position = 0.802 
kernelsize7_position = [0.7637, 0.7321, 0.7167, 0.714, 0.7105, 0.7115, 0.6983] 
kernelsize5_position = [0.7733, 0.7263, 0.7127, 0.713, 0.7092] 
kernelsize4_position = [0.7785, 0.7258, 0.7115, 0.7079] 
kernelsize3_position = [0.7942, 0.7301, 0.7212] 
kernelsize2_position = [0.792, 0.735] 
# kernelsize1_position = [0.8125] 
kernelsize1_position = 0.8125 
# finetuned = 0.6954 
finetuned = 0.691 
# plain = 0.6362 
plain = 0.6535

# %%
def plotingforonesetting(title_name): 
    plt.plot(list(range(1, 8)), kernelsize7_position, label = 'kernelsize7', marker = 'o', color = 'blue') 
    plt.plot(list(range(1, 6)), kernelsize5_position, label = 'kernelsize5', marker = 'v', color = 'purple') 
    plt.plot(list(range(1, 5)), kernelsize4_position, label = 'kernelsize4', marker = 's', color = 'orange') 
    plt.plot(list(range(1, 4)), kernelsize3_position, label = 'kernelsize3', marker = 'D', color = 'cyan') 
    plt.plot(list(range(1, 3)), kernelsize2_position, label = 'kernelsize2', marker = 'x', color = 'green') 
    plt.plot(1, kernelsize1_position, label = 'kernelsize1', marker = 'p', color = 'red') 

    # ploting horizontal line 
    plt.axhline(y = finetuned, color = 'black', linestyle = "--", label = 'small model finetuned') 
    plt.axhline(y = plain, color = 'green', linestyle = '--', label = 'small model plain') 
    plt.annotate('small model finetuned', xy = (7, finetuned), xytext = (7.5, finetuned), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
    plt.annotate('small model plain', xy = (7, plain), xytext = (7.5, plain), arrowprops = dict(facecolor = 'green', arrowstyle = '->')) 

    plt.xlabel("Position After the Condensed Token") 
    plt.ylabel("Acceptance Rate") 
    plt.grid() 
    plt.legend() 
    # plt.title("C4 first 64 tokens") 
    plt.title(title_name) 

    plt.show() 

plotingforonesetting("C4 first 64 tokens")

# %%
# kernelsize7_position = [0.618, 0.521, 0.504, 0.509, 0.507, 0.489, 0.518] 
kernelsize7_position = [0.5624, 0.4852, 0.4681, 0.4574, 0.46, 0.47, 0.4604] 
kernelsize5_position = [0.5761, 0.4948, 0.4723, 0.464, 0.4676] 
kernelsize4_position = [0.5763, 0.491, 0.466, 0.4641] 
kernelsize3_position = [0.612, 0.4974, 0.4731] 
kernelsize2_position = [0.6331, 0.5023] 
kernelsize1_position = 0.659 
# kernelsize2_position = [0.679, 0.57] 
# kernelsize1_position = 0.69 
# finetuned = 0.492 
finetuned = 0.478 
# plain = 0.417 
plain = 0.421

# %%
plotingforonesetting("PG19 middle 64 tokens")

# %%
# kernelsize7_position = [0.742, 0.72, 0.684, 0.657, 0.665, 0.653, 0.677] 
kernelsize7_position = [0.7461, 0.694, 0.6827, 0.6834, 0.6711, 0.6683, 0.6634] 
kernelsize5_position = [0.7538, 0.6952, 0.6766, 0.6719, 0.6655] 
kernelsize4_position = [0.7565, 0.6981, 0.6866, 0.672] 
kernelsize3_position = [0.7661, 0.6986, 0.6785] 
# kernelsize2_position = [0.791, 0.701] 
kernelsize2_position = [0.7867, 0.6946] 
# kernelsize1_position = 0.77 
kernelsize1_position = 0.797 
# finetuned = 0.655 
finetuned = 0.6724 
# plain = 0.641 
plain = 0.6259

# %%
plotingforonesetting("OpenWebText first 64 tokens")

# %%
c4_synthesized = [7.21, 7.25, 7.42, 7.87, 7.85, 8.03] 
c4 = [13.34, 12.70, 13.48, 14.49, 14.65, 15.18] 
# pg19 = [24.20, 29.81, 32.76, 34.95, 36.64, 38.01] 
openwebtext = [13.01, 12.83, 13.37, 14.09, 14.48, 15.21] 
cnn = [11.87, 11.77, 12.28, 12.97, 13.32, 14.03] 
xsum = [11.51, 11.31, 11.84, 12.62, 12.85, 13.49] 

checkpoint_list = [1, 2, 3, 4, 5, 7] 

# plt.plot(checkpoint_list, c4_synthesized, label='c4_synthesized', marker='x') 
plt.plot(checkpoint_list, c4_synthesized, label = "c4_synthesized *", marker = 'x') 
plt.plot(checkpoint_list, c4, label='c4', marker = "x") 
# plt.plot(checkpoint_list, pg19, label='pg19', marker = "x") 
plt.plot(checkpoint_list, openwebtext, label='openwebtext', marker = "x") 
plt.plot(checkpoint_list, cnn, label='cnn', marker = "x") 
plt.plot(checkpoint_list, xsum, label='xsum', marker = "x") 
plt.xlabel("kernel size") 
plt.ylabel("perplexity") 
plt.axhline(y = 8.72, color = 'tab:blue', linestyle = "--") 
plt.annotate('small model c4_synthesized\nfinetuned baseline', xy = (7, 8.72), xytext = (7.5, 8.72), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
plt.grid() 
plt.legend() 
plt.title("Perplexity of different datasets with different kernel sizes (Without PG19)") 
plt.show()

# %%
c4_synthesized = [7.21, 7.25, 7.42, 7.87, 7.85, 8.03] 
c4 = [13.34, 12.70, 13.48, 14.49, 14.65, 15.18] 
pg19 = [24.20, 29.81, 32.76, 34.95, 36.64, 38.01] 
openwebtext = [13.01, 12.83, 13.37, 14.09, 14.48, 15.21] 
cnn = [11.87, 11.77, 12.28, 12.97, 13.32, 14.03] 
xsum = [11.51, 11.31, 11.84, 12.62, 12.85, 13.49] 

checkpoint_list = [1, 2, 3, 4, 5, 7] 

plt.plot(checkpoint_list, c4_synthesized, label='c4_synthesized', marker='x') 
plt.plot(checkpoint_list, c4, label='c4', marker = "x") 
plt.plot(checkpoint_list, pg19, label='pg19', marker = "x") 
plt.plot(checkpoint_list, openwebtext, label='openwebtext', marker = "x") 
plt.plot(checkpoint_list, cnn, label='cnn', marker = "x") 
plt.plot(checkpoint_list, xsum, label='xsum', marker = "x") 
plt.xlabel("kernel size") 
plt.ylabel("perplexity") 
plt.axhline(y = 46.14, color = 'tab:green', linestyle = "--") 
plt.annotate('small model PG19\nfinetuned baseline', xy = (7, 45.14), xytext = (7.5, 45.14), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
plt.grid() 
plt.legend() 
plt.title("Perplexity of different datasets with different kernel sizes (With PG19)") 
plt.show()

# %%
c4 = [13.34, 12.70, 13.48, 14.49, 14.65, 15.18] 
c4_setting3 = [13.54, 18.20, 21.01, 22.60, 23.65, 24.38] 
checkpoint_list = [1, 2, 3, 4, 5, 7] 
plt.plot(checkpoint_list, c4, label='c4 setting0', marker = "x") 
plt.plot(checkpoint_list, c4_setting3, label='c4 setting3', marker = "x", linestyle = "--") 
plt.axhline(y = 16.83, color = 'tab:green', linestyle = "--") 
plt.annotate('small model C4\nfinetuned baseline', xy = (7, 16.83), xytext = (7.5, 16.83), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
plt.xlabel("kernel size") 
plt.ylabel("perplexity") 
plt.grid() 
plt.legend() 
plt.title("Perplexity of C4 with different kernel sizes (Setting0 and Setting3)") 
plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize = (15, 10)) 
datasetname = ["c4", "pg19", "openwebtext", "cnn", "xsum"] 
x = [1, 2, 4, 7] 
tinyllamasmall = [[13.34, 24.20, 13.01, 11.87, 11.51], 
                  [12.70, 29.81, 12.83, 11.77, 11.31], 
                  [14.49, 34.95, 14.09, 12.97, 12.62], 
                  [15.18, 38.01, 15.21, 14.03, 13.49]] 
tinyllamasmall = np.array(tinyllamasmall) 
tinyllamasmall = tinyllamasmall.T 

llama27bsmall = [[13.43, 24.74, 13.45, 12.12, 11.15], 
                 [14.76, 39.51, 15.13, 13.21, 12.77], 
                 [14.50, 40.96, 14.91, 13.46, 12.69], 
                 [15.85, 48.54, 16.95, 15.28, 14.24]] 
llama27bsmall = np.array(llama27bsmall) 
llama27bsmall = llama27bsmall.T 

for i, axis in enumerate(ax.flat[:5]): 
    axis.plot(x, tinyllamasmall[i], label = "TinyLlama1.1B + Small model", marker = 'o') 
    axis.plot(x, llama27bsmall[i], label = "Llama2 7B + Small model", marker = 'o') 
    axis.set_title(datasetname[i]) 
    axis.grid() 
    axis.legend() 
    axis.set_xlabel("kernel size") 

ax.flat[5].set_visible(False) 

plt.tight_layout() 

plt.show()

# %%
# Plot the graph comparing different large model setting3 
fig, ax = plt.subplots(2, 3, figsize = (15, 10)) 
datasetname = ["c4", "pg19", "openwebtext", "cnn", "xsum"] 
x = [1, 2, 4, 7] 
tinyllamasmall = [[13.54, 24.57, 13.29, 12.18, 11.74], 
                  [18.20, 42.64, 18.45, 17.81, 16.11], 
                  [23.65, 59.12, 23.75, 24.48, 20.13], 
                  [24.38, 65.67, 25.92, 27.48, 21.90]] 
tinyllamasmall = np.array(tinyllamasmall) 
tinyllamasmall = tinyllamasmall.T 

llama27bsmall = [[11.84, 22.91, 11.90, 10.49, 10.55], 
                 [17.31, 45.50, 17.91, 16.33, 15.53], 
                 [23.40, 69.18, 25.51, 24.88, 21.07], 
                 [25.11, 77.36, 28.01, 27.91, 22.73]] 
llama27bsmall = np.array(llama27bsmall) 
llama27bsmall = llama27bsmall.T 

for i, axis in enumerate(ax.flat[:5]): 
    axis.plot(x, tinyllamasmall[i], label = "TinyLlama1.1B + Small model", marker = 'o') 
    axis.plot(x, llama27bsmall[i], label = "Llama2 7B + Small model", marker = 'o') 
    axis.set_title(datasetname[i]) 
    axis.grid() 
    axis.legend() 
    axis.set_xlabel("kernel size") 

ax.flat[5].set_visible(False) 

plt.tight_layout() 

plt.show()

# %%
checkpointposition = list(range(1, 8)) 
kernelsize7acceptancerate = [0.7637, 0.7321, 0.7167, 0.714, 0.7105, 0.7115, 0.6983] 
kernelsize3acceptancerate = [0.7858, 0.7327, 0.7182, 0.7012, 0.7012, 0.6766, 0.6442] 
kernelsize2acceptancerate = [0.7954, 0.7274, 0.6976, 0.693, 0.6839, 0.645, 0.6099] 
mixedkernelsizeacceptancerate = [0.7848, 0.7257, 0.7154, 0.7129, 0.7138, 0.7032, 0.7047] 
finetuned = 0.691 
plain = 0.6535 

plt.plot(checkpointposition, kernelsize7acceptancerate, label = 'kernelsize7', color = 'orange', marker = 'o') 
plt.plot(checkpointposition, kernelsize3acceptancerate, label = 'kernelsize3', color = 'green', marker = 'v') 
plt.plot(checkpointposition, kernelsize2acceptancerate, label = 'kernelsize2', color = 'blue', marker = 's') 
plt.plot(checkpointposition, mixedkernelsizeacceptancerate, label = "mixed kernelsize", color = 'purple', marker = 'o') 
plt.axhline(y = finetuned, color = 'black', linestyle = "--", label = 'small model finetuned') 
plt.axhline(y = plain, color = 'green', linestyle = '--', label = 'small model plain') 
plt.annotate('small model finetuned', xy = (7, finetuned), xytext = (7.5, finetuned), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
plt.annotate('small model plain', xy = (7, plain), xytext = (7.5, plain), arrowprops = dict(facecolor = 'green', arrowstyle = '->')) 
plt.xlabel("Position After the Condensed Token") 
plt.ylabel("Acceptance Rate") 
plt.title("C4 first 64 tokens") 

plt.grid() 
plt.legend() 
plt.show()

# %%
checkpointposition = list(range(1, 8)) 
kernelsize7acceptancerate = [0.5624, 0.4852, 0.4681, 0.4574, 0.46, 0.47, 0.4604] 
kernelsize3acceptancerate = [0.6087, 0.4934, 0.4739, 0.46, 0.4591, 0.4375, 0.4191] 
kernelsize2acceptancerate = [0.6254, 0.4835, 0.4577, 0.4508, 0.4426, 0.4153, 0.3855] 
mixedkernelsizeacceptancerate = [0.5877, 0.4985, 0.4787, 0.4718, 0.4717, 0.4729, 0.4758] 
# finetuned = 0.478 
finetuned = 0.476 
# plain = 0.421 
plain = 0.432 

plt.plot(checkpointposition, kernelsize7acceptancerate, label = 'kernelsize7', color = 'orange', marker = 'o') 
plt.plot(checkpointposition, kernelsize3acceptancerate, label = 'kernelsize3', color = 'green', marker = 'v') 
plt.plot(checkpointposition, kernelsize2acceptancerate, label = 'kernelsize2', color = 'blue', marker = 's') 
plt.plot(checkpointposition, mixedkernelsizeacceptancerate, label = 'mixed kernelsize', color = 'purple', marker = 'o') 
plt.axhline(y = finetuned, color = 'black', linestyle = "--", label = 'small model finetuned') 
plt.axhline(y = plain, color = 'green', linestyle = '--', label = 'small model plain') 
plt.annotate('small model finetuned', xy = (7, finetuned), xytext = (7.5, finetuned), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
plt.annotate('small model plain', xy = (7, plain), xytext = (7.5, plain), arrowprops = dict(facecolor = 'green', arrowstyle = '->')) 
plt.xlabel("Position After the Condensed Token") 
plt.ylabel("Acceptance Rate") 
plt.title("PG19 first 64 tokens") 

plt.grid() 
plt.legend() 
plt.show()

# %%
checkpointposition = list(range(1, 8)) 
kernelsize7acceptancerate = [0.7461, 0.694, 0.6827, 0.6834, 0.6711, 0.6683, 0.6634] 
kernelsize3acceptancerate = [0.7669, 0.6902, 0.6788, 0.6736, 0.6601, 0.6229, 0.6008] 
kernelsize2acceptancerate = [0.7737, 0.6921, 0.6666, 0.6619, 0.6553, 0.6141, 0.5676] 
mixedkernelsizeacceptancerate = [0.7555, 0.7008, 0.6886, 0.6778, 0.6777, 0.6719, 0.671] 
# finetuned = 0.6724 
finetuned = 0.6663 
# plain = 0.6259 
plain = 0.6307 

plt.plot(checkpointposition, kernelsize7acceptancerate, label = 'kernelsize7', color = 'orange', marker = 'o') 
plt.plot(checkpointposition, kernelsize3acceptancerate, label = 'kernelsize3', color = 'green', marker = 'v') 
plt.plot(checkpointposition, kernelsize2acceptancerate, label = 'kernelsize2', color = 'blue', marker = 's') 
plt.plot(checkpointposition, mixedkernelsizeacceptancerate, label = 'mixed kernelsize', color = 'purple', marker = 'o') 
plt.axhline(y = finetuned, color = 'black', linestyle = "--", label = 'small model finetuned') 
plt.axhline(y = plain, color = 'green', linestyle = '--', label = 'small model plain') 
plt.annotate('small model finetuned', xy = (7, finetuned), xytext = (7.5, finetuned), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
plt.annotate('small model plain', xy = (7, plain), xytext = (7.5, plain), arrowprops = dict(facecolor = 'green', arrowstyle = '->')) 
plt.xlabel("Position After the Condensed Token") 
plt.ylabel("Acceptance Rate") 
plt.title("OpenWebText first 64 tokens") 

plt.grid() 
plt.legend() 
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize = (15, 5)) 
datasetname = ["c4", "pg19", "openwebtext"] 
kernelsize7acceptancerate = [[0.7637, 0.7321, 0.7167, 0.714, 0.7105, 0.7115, 0.6983], 
                             [0.5624, 0.4852, 0.4681, 0.4574, 0.46, 0.47, 0.4604], 
                             [0.7461, 0.694, 0.6827, 0.6834, 0.6711, 0.6683, 0.6634]] 
mixedkernelsizeacceptancerate = [[0.7848, 0.7257, 0.7154, 0.7129, 0.7138, 0.7032, 0.7047],
                                 [0.5877, 0.4985, 0.4787, 0.4718, 0.4717, 0.4729, 0.4758],
                                 [0.7555, 0.7008, 0.6886, 0.6778, 0.6777, 0.6719, 0.671]] 
finetuned = [0.691, 0.476, 0.6663] 
plain = [0.6535, 0.432, 0.6307] 

for i, axis in enumerate(ax.flat): 
    axis.plot(checkpointposition, kernelsize7acceptancerate[i], label = 'kernelsize7', color = 'orange', marker = 'o') 
    axis.plot(checkpointposition, mixedkernelsizeacceptancerate[i], label = 'mixed kernelsize', color = 'purple', marker = 'o') 
    axis.axhline(y = finetuned[i], color = 'black', linestyle = "--", label = 'small model finetuned') 
    axis.axhline(y = plain[i], color = 'green', linestyle = '--', label = 'small model plain') 
    # axis.annotate('small model finetuned', xy = (7, finetuned[i]), xytext = (7.5, finetuned[i]), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
    # axis.annotate('small model finetuned', xy = (7, finetuned[i]), xytext = (4.5, finetuned[i] - 0.01), arrowprops = dict(facecolor = 'black', arrowstyle = '->')) 
    # axis.annotate('small model plain', xy = (7, plain[i]), xytext = (7.5, plain[i]), arrowprops = dict(facecolor = 'green', arrowstyle = '->')) 
    axis.set_xlabel("Position After the Condensed Token") 
    axis.set_ylabel("Acceptance Rate") 
    axis.set_title(datasetname[i]) 
    axis.grid() 
    axis.legend() 

plt.tight_layout() 
plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize = (15, 10)) 
dataset = ["synthesized", "c4", "pg19", "openwebtext", "cnn", "xsum"] 
x = [1, 2, 4, 7] 
sevendifferentmodel = [[7.21, 13.34, 24.20, 13.01, 11.87, 11.51], 
                       [7.25, 12.70, 29.81, 12.83, 11.77, 11.31], 
                       [7.87, 14.49, 34.95, 14.09, 12.97, 12.62], 
                       [8.03, 15.18, 38.01, 15.21, 14.03, 13.49]] 
sevendifferentmodel = np.array(sevendifferentmodel) 
sevendifferentmodel = sevendifferentmodel.T 

mixedkernelsize = [[7.64, 15.30, 27.88, 13.85, 12.63, 12.66], 
                   [7.27, 14.27, 29.72, 13.00, 11.93, 11.95], 
                   [7.64, 14.64, 33.88, 14.01, 12.92, 12.62], 
                   [8.00, 15.18, 37.24, 15.13, 14.01, 13.44]] 
mixedkernelsize = np.array(mixedkernelsize) 
mixedkernelsize = mixedkernelsize.T 

kernelsizesevenextrapolate = [[7.82, 15.92, 30.34, 14.28, 13.01, 13.09], 
                              [7.38, 14.64, 31.17, 13.30, 12.18, 12.25], 
                              [7.69, 14.77, 34.76, 14.14, 13.00, 12.76], 
                              [8.03, 15.18, 38.01, 15.21, 14.03, 13.49]] 
kernelsizesevenextrapolate = np.array(kernelsizesevenextrapolate) 
kernelsizesevenextrapolate = kernelsizesevenextrapolate.T 

kernelsizeoneextrapolate = [[7.21, 13.34, 24.20, 13.01, 11.87, 11.51], 
                            [9.36, 16.75, 35.59, 17.60, 16.71, 15.00], 
                            [11.85, 20.90, 51.07, 24.12, 23.51, 19.46], 
                            [13.55, 24.03, 62.26, 29.28, 29.19, 22.86]] 
kernelsizeoneextrapolate = np.array(kernelsizeoneextrapolate) 
kernelsizeoneextrapolate = kernelsizeoneextrapolate.T 

for i, axis in enumerate(ax.flat): 
    axis.plot(x, sevendifferentmodel[i], label = "7 different model", marker = 'o') 
    axis.plot(x, mixedkernelsize[i], label = "mixed kernelsize", marker = 'o') 
    axis.plot(x, kernelsizesevenextrapolate[i], label = "extrapolate", marker = 'o') 
    # axis.plot(x, kernelsizeoneextrapolate[i], label = "extrapolate one", marker = 'o') 
    axis.set_title(dataset[i]) 
    axis.grid() 
    axis.legend() 
    axis.set_xlabel("kernel size") 

plt.tight_layout() 
plt.show()

# %%
gamma = ["gamma = 1", "gamma = 2", "gamma = 3", "gamma = 4", "gamma = 6"] 
avgaccepted = [[0.68, 1.18, 1.52, 1.76, 2.00], 
               [0.732, 1.27, 1.70, 1.94, 2.34], 
               [0.79, 1.38, 1.84, 2.21, 2.79]] 
idx = list(range(5)) 

labelleg = ["Plain", "Finetuned", "LargeHiddenStates"] 
width = 0.2 
fig, ax = plt.subplots() 
for i in range(3): 
    ax.bar([p + width*i for p in idx], avgaccepted[i], width, label = labelleg[i]) 

ax.set_xlabel("Different gamma values") 
ax.set_ylabel("Average Accepted Tokens - 1") 
ax.set_title("C4 dataset prefill 64 generate 64") 
ax.set_xticks([x + width for x in idx]) 
ax.set_xticklabels(gamma) 

# plt.xticks(rotation = 45) 
plt.tight_layout() 
plt.grid() 

ax.legend()

# %%
avgaccepted = [[0.500, 0.783, 0.924, 1.00, 1.06], 
               [0.561, 0.90, 1.08, 1.18, 1.27], 
               [0.639, 1.02, 1.23, 1.42, 1.71]] 
gamma = ["gamma = 1", "gamma = 2", "gamma = 3", "gamma = 4", "gamma = 5"] 
idx = list(range(5)) 

labelleg = ["Plain", "Finetuned", "LargeHiddenStates"] 
width = 0.2 
fig, ax = plt.subplots() 
for i in range(3): 
    ax.bar([p + width*i for p in idx], avgaccepted[i], width, label = labelleg[i]) 

ax.set_xlabel("Different gamma values") 
ax.set_ylabel("Average Accepted Tokens - 1") 
# ax.set_title("C4 dataset prefill 64 generate 64") 
ax.set_title("PG19 dataset prefill 64 generate 64") 
ax.set_xticks([x + width for x in idx]) 
ax.set_xticklabels(gamma) 

# plt.xticks(rotation = 45) 
plt.tight_layout() 
plt.grid() 

ax.legend()

# %%
avgaccepted = [[0.641, 1.11, 1.37, 1.58, 1.77], 
               [0.701, 1.21, 1.55, 1.80, 2.11], 
               [0.748, 1.30, 1.725, 2.07, 2.46]] 
gamma = ["gamma = 1", "gamma = 2", "gamma = 3", "gamma = 4", "gamma = 5"] 
idx = list(range(5)) 

labelleg = ["Plain", "Finetuned", "LargeHiddenStates"] 
width = 0.2 
fig, ax = plt.subplots() 
for i in range(3): 
    ax.bar([p + width*i for p in idx], avgaccepted[i], width, label = labelleg[i]) 

ax.set_xlabel("Different gamma values") 
ax.set_ylabel("Average Accepted Tokens - 1") 
# ax.set_title("PG19 dataset prefill 64 generate 64") 
ax.set_title("OpenWebText dataset prefill 64 generate 64") 
ax.set_xticks([x + width for x in idx]) 
ax.set_xticklabels(gamma) 

# plt.xticks(rotation = 45) 
plt.tight_layout() 
plt.grid() 

ax.legend()

# %%
avgaccepted = [[0.68, 1.18, 1.42], 
               [0.69, 1.50, 1.99], 
               [0.76, 1.71, 2.44]] 

gamma = ["gamma = 1", "gamma = 3", "gamma = 5"] 
idx = list(range(3)) 

labelleg = ["Plain", "Finetuned", "LargeHiddenStates"] 
width = 0.15 
fig, ax = plt.subplots() 
for i in range(3): 
    ax.bar([p + width*i for p in idx], avgaccepted[i], width, label = labelleg[i]) 

ax.set_xlabel("Different gamma values") 
ax.set_ylabel("Average Accepted Tokens - 1") 
# ax.set_title("PG19 dataset prefill 64 generate 64") 
ax.set_title("C4 dataset prefill 64 generate 64") 
ax.set_xticks([x + width for x in idx]) 
ax.set_xticklabels(gamma) 

# plt.xticks(rotation = 45) 
plt.tight_layout() 
plt.grid() 

ax.legend()

# %%
avgaccepted = [[0.49, 0.68, 0.72], [0.50, 0.87, 0.97], [0.59, 1.23, 1.51]] 
gamma = ["gamma = 1", "gamma = 3", "gamma = 5"] 
idx = list(range(3)) 

labelleg = ["Plain", "Finetuned", "LargeHiddenStates"] 
width = 0.15 
fig, ax = plt.subplots() 
for i in range(3): 
    ax.bar([p + width*i for p in idx], avgaccepted[i], width, label = labelleg[i]) 

ax.set_xlabel("Different gamma values") 
ax.set_ylabel("Average Accepted Tokens - 1") 
# ax.set_title("PG19 dataset prefill 64 generate 64") 
ax.set_title("PG19 dataset prefill 64 generate 64") 
ax.set_xticks([x + width for x in idx]) 
ax.set_xticklabels(gamma) 

# plt.xticks(rotation = 45) 
plt.tight_layout() 
plt.grid() 

ax.legend()

# %%
avgaccepted = [[0.61, 1.01, 1.16], [0.64, 1.37, 1.77], [0.71, 1.55, 2.07]] 
gamma = ["gamma = 1", "gamma = 3", "gamma = 5"] 
idx = list(range(3)) 

labelleg = ["Plain", "Finetuned", "LargeHiddenStates"] 
width = 0.15 
fig, ax = plt.subplots() 
for i in range(3): 
    ax.bar([p + width*i for p in idx], avgaccepted[i], width, label = labelleg[i]) 

ax.set_xlabel("Different gamma values") 
ax.set_ylabel("Average Accepted Tokens - 1") 
# ax.set_title("PG19 dataset prefill 64 generate 64") 
ax.set_title("OpenWebText dataset prefill 64 generate 64") 
ax.set_xticks([x + width for x in idx]) 
ax.set_xticklabels(gamma) 

# plt.xticks(rotation = 45) 
plt.tight_layout() 
plt.grid() 

ax.legend()

# %%
weights_assign = [] 
for i in range(1, 8): 
    for j in range(len(weights_assign)): 
        weights_assign[j] += 1/i  
    weights_assign.append(1/i) 
    print(weights_assign) 
print(weights_assign) 
weights_assign = [x/weights_assign[-1] for x in weights_assign]
# Out:
# [1.0]
# [1.5, 0.5]
# [1.8333333333333333, 0.8333333333333333, 0.3333333333333333]
# [2.083333333333333, 1.0833333333333333, 0.5833333333333333, 0.25]
# [2.283333333333333, 1.2833333333333332, 0.7833333333333332, 0.45, 0.2]
# [2.4499999999999997, 1.45, 0.9499999999999998, 0.6166666666666667, 0.3666666666666667, 0.16666666666666666]
# [2.5928571428571425, 1.5928571428571427, 1.0928571428571427, 0.7595238095238095, 0.5095238095238095, 0.30952380952380953, 0.14285714285714285]
# [2.5928571428571425, 1.5928571428571427, 1.0928571428571427, 0.7595238095238095, 0.5095238095238095, 0.30952380952380953, 0.14285714285714285]

# %%
weights_assign
# Out:
# [18.15,
#  11.15,
#  7.6499999999999995,
#  5.316666666666666,
#  3.5666666666666664,
#  2.166666666666667,
#  1.0]

# %%
### Given the same dataset, different evaluation performance 
import matplotlib.pyplot as plt
import numpy as np

# Define the categories and data
# categories = ['Category 1', 'Category 2', 'Category 3', 'Category 4', 'Category 5']
categories = ["C4", "PG19", "OpenWebText", "CNN/DailyMail", "XSum"] 
# group_a = np.random.rand(5) * 100  # Random data for Group A 
group_a = [11.67, 48.89, 15.32, 11.74, 11.09] 
# group_b = np.random.rand(5) * 100  # Random data for Group B 
group_b = [10.72, 41.28, 13.37, 10.21, 9.87] 

# Positions for the groups
# bar_width = 0.35 
bar_width = 0.2 
index = np.arange(len(categories))

# Creating the bar plot
fig, ax = plt.subplots()
bars1 = ax.bar(index - bar_width/2, group_a, bar_width, label="TinyLlama Hidden States") 
bars2 = ax.bar(index + bar_width/2, group_b, bar_width, label="Llama2_7B Hidden States") 

# Adding labels and title
ax.set_xlabel("Different Datasets") 
ax.set_ylabel("PPL") 
ax.set_title("Kernel Size 2 (Evaluation in PPL)") 
ax.set_xticks(index)
ax.set_xticklabels(categories)
ax.legend()

# Show the plot
plt.grid() 
plt.show()

# %%
### Given the same dataset, different evaluation performance 
import matplotlib.pyplot as plt
import numpy as np

# Define the categories and data
# categories = ['Category 1', 'Category 2', 'Category 3', 'Category 4', 'Category 5']
categories = ["C4", "PG19", "OpenWebText", "CNN/DailyMail", "XSum"] 
# group_a = np.random.rand(5) * 100  # Random data for Group A 
group_a = [12.38, 55.42, 16.58, 12.82, 11.92] 
# group_b = np.random.rand(5) * 100  # Random data for Group B 
group_b = [11.87, 51.08, 15.34, 11.95, 11.22] 

# Positions for the groups
# bar_width = 0.35 
bar_width = 0.2 
index = np.arange(len(categories))

# Creating the bar plot
fig, ax = plt.subplots()
bars1 = ax.bar(index - bar_width/2, group_a, bar_width, label="TinyLlama Hidden States") 
bars2 = ax.bar(index + bar_width/2, group_b, bar_width, label="Llama2_7B Hidden States") 

# Adding labels and title
ax.set_xlabel("Different Datasets") 
ax.set_ylabel("PPL") 
ax.set_title("Kernel size 4 (Evaluation in PPL)") 
ax.set_xticks(index)
ax.set_xticklabels(categories)
ax.legend()

# Show the plot
plt.grid() 
plt.show()

# %%
### Given the same dataset, different evaluation performance 
import matplotlib.pyplot as plt
import numpy as np

# Define the categories and data
# categories = ['Category 1', 'Category 2', 'Category 3', 'Category 4', 'Category 5']
categories = ["C4", "PG19", "OpenWebText", "CNN/DailyMail", "XSum"] 
# group_a = np.random.rand(5) * 100  # Random data for Group A 
group_a = [13.29, 61.23, 18.05, 13.96, 12.90] 
# group_b = np.random.rand(5) * 100  # Random data for Group B 
group_b = [12.96, 58.23, 17.11, 13.32, 12.38] 

# Positions for the groups
# bar_width = 0.35 
bar_width = 0.2 
index = np.arange(len(categories))

# Creating the bar plot
fig, ax = plt.subplots()
bars1 = ax.bar(index - bar_width/2, group_a, bar_width, label="TinyLlama Hidden States") 
bars2 = ax.bar(index + bar_width/2, group_b, bar_width, label="Llama2_7B Hidden States") 

# Adding labels and title
ax.set_xlabel("Different Datasets") 
ax.set_ylabel("PPL") 
ax.set_title("Kernel Size 7 (Evaluation in PPL)") 
ax.set_xticks(index)
ax.set_xticklabels(categories)
ax.legend()

# Show the plot
plt.grid() 
plt.show()

# %%
plt.plot(list(range(1, 8)), weights_assign, marker = 'o', label = "adjusted weight") 
plt.plot(list(range(1, 8)), [7 - i for i in range(7)], marker = 'o', label = "Another way") 
plt.grid() 
plt.legend() 
plt.show()

# %% [markdown]
# ### Small model

# %%
# <s> The Bicycle® brand celebrates North America's (US and Canada) craft brewing spirit. A spirit that captures the passion for their craft, signature look as well as product, and th
# e entrepreneurial drive to turn a hobby into a business. Each of the 52 companies in the U . S . are listed on the B icy cle ® brand .                                               
#  The B icy cle ® brand is a global leader in the manufact uring of hand b ags , j ew el ry , access ories , access ories , and more . Our products are designed to insp ire the cre a
# tive and cre ative minds to create something truly special .                                                                                                                         
#  B icy cle ® is a registered tra dem ark of B icy cle ® . <unk> A few days ago , I had a couple of days off from work , and I was supposed to have a new job . The first day was goin
# g to be the day I got home , and the next day I got the job . I was supposed to be working at the end of the day , but I was able to take the time to do my best to do my job .      
#  I had been working for a couple of days . I had been working in the office for  5 months and had been in the office for  1 2 months . I had been working for a few days , and then i
# t was all over again . I had been working for a few days , and I was actually working for a few days , and I was able to do a few days , and I was able to get a job . 
entropies = [3.7860909, 2.9954977, 0.00010629839, 2.41445, 0.000106298394, 0.000106298394, 0.000106298394, 2.6997278, 5.1927347, 1.7854282, 0.00010629839, 1.6182823, 1.502547, 0.00010629839, 0.000106298394, 0.93629503, 1.9376622, 0.44260725, 2.8813014, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.84521365, 2.303826, 4.847817, 1.3828291, 0.00010629839, 0.49891233, 3.1507585, 0.9923216, 0.66527814, 2.9751515, 1.6803967, 0.00010629839, 0.4718809, 2.5730567, 0.00010629839, 0.5656182, 0.00010629839, 0.000106298394, 1.9017863, 0.00010629839, 0.76517355, 1.5606742, 0.00010629839, 0.73229396, 1.0701072, 2.7041247, 0.000106298394, 2.4388266, 4.218169, 0.57915115, 3.1629033, 0.5061617, 2.7554452, 0.00010629839, 2.242042, 2.457032, 0.9923213, 2.1944926, 3.2092507, 0.00010629839, 1.4089805, 1.4219352, 0.84315664, 2.6294715, 2.1152236, 0.53350025, 0.77426326, 1.7495006, 2.5403752, 0.00010629839, 0.5656183, 0.000106298394, 1.1488429, 0.5022125, 2.072681, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0
.00010629839, 0.000106298394, 2.1093862, 3.0010524, 0.38752064, 0.92937434, 1.1575004, 1.0123078, 1.5470707, 0.90828294, 2.7594337, 2.4930522, 1.4283965, 0.00010629839, 1.6095622, 0.25189006, 3.0100703, 1.5631139, 0.000106298394, 1.3971004, 0.00010629839, 0.00010629839, 0.00010629839, 0.4426067, 1.111141, 0.00010629839, 2.1395233, 0.855399, 0.00010629839, 0.00010629839, 0.59841317, 0.00010629839, 0.00010629839, 2.1210914, 1.908472, 0.00010629839, 0.82186687, 0.00010629839, 0.00010629839, 0.00010629839, 0.72929144, 1.0217692, 0.0001029839, 0.4718809, 0.00010629839, 0.00010629839, 0.00010629839, 0.631703, 0.53350025, 0.00010629839, 0.36180177, 0.00010629839, 0.00010629839, 0.00010629839, 0.9329585, 0.47188085, 0.00010629839, 0.31411666, 0.00010629839, 0.00010629839, 0.00010629839, 0.9827079, 0.47188085, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.8849621, 0.41446802, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.69889724, 0.47188085, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.23353775, 0.00010629839, 0.00010629839, 0.00010629839, 0.9527969, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.69889724, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.76517355, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.8281001, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.82810056, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.73229337, 0.00010629839, 0.00010629839, 0.000106298394, 0.47188085, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.73229396, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.76517355, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.6652781, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.5335002, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.000106298394, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839, 0.00010629839] 
plt.plot(list(range(1, len(entropies) + 1)), entropies, marker = 'o') 
plt.grid() 
plt.plot()
# Out:
# []

# %% [markdown]
# ### LLM

# %%
from transformers import AutoTokenizer 
from transformers import LlamaTokenizer 
tokenizer1 = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-128k-instruct") 
tokenizer2 = LlamaTokenizer.from_pretrained("meta-llama/Llama-2-7b") 
# text = "The quick brown fox jumps over the lazy dog" 
text = "Based on our estimated compute-optimal frontier, we predict that for the compute budget used \
to train Gopher, an optimal model should be 4 times smaller, while being training on 4 times more \
tokens. We verify this by training a more compute-optimal 70B model, called Chinchilla, on 1.4 trillion \
tokens. Not only does Chinchilla outperform its much larger counterpart, Gopher, but its reduced \
model size reduces inference cost considerably and greatly facilitates downstream uses on smaller \
hardware. The energy cost of a large language model is amortized through its usage for inference an \
fine-tuning. The benefits of a more optimally trained smaller model, therefore, extend beyond the \
immediate benefits of its improved performance." 
tokens1 = tokenizer1(text) 
tokens2 = tokenizer2(text) 
print(tokens1) 
print(tokens2) 
print(tokens1 == tokens2)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
onell = [4.1363e+00, 4.1359e+00, 1.1219e+00, 2.1324e+00, 1.8053e+00, 1.2367e+01,                                                             
        2.5087e+00, 2.8132e-01, 7.7741e+00, 1.6921e+00, 2.9301e-01, 4.6814e+00,                                                             
        3.4414e+00, 2.1617e+00, 4.7250e+00, 2.6473e+00, 4.9378e+00, 3.9166e+00,                                                             
        8.5397e-01, 7.5832e+00, 3.7308e+00, 5.7174e+00, 4.1107e+00, 1.6382e+00,                                                             
        1.7940e-03, 6.4894e-01, 3.0048e+00, 6.0560e+00, 2.6961e+00, 7.1777e+00,                                                             
        3.3295e-01, 6.3843e+00, 3.3625e+00, 5.5513e+00, 2.5022e+00, 5.8993e+00,                                                             
        5.9525e+00, 2.4101e+00, 6.2605e-01, 1.9216e+00, 7.6214e-02, 1.0121e-03,                                                             
        2.0496, 2.0501, 2.0061, 1.9018, 1.9920, 2.0045, 2.0026, 2.0934, 2.0592,
        2.0227, 1.9615, 2.0473, 1.9137, 2.0435, 1.9452, 1.9687, 2.0965, 2.0214,
        1.9525, 2.0718, 1.9308, 2.0052, 2.0860, 1.9913, 2.0263, 2.0093, 2.0128,
        1.9749, 2.0173, 2.0587, 2.0752, 1.9585, 1.9500, 2.1050, 1.9658, 2.0713,
        1.9536, 2.0003, 1.8913, 2.0049, 2.0076, 2.0662, 2.0434, 2.0649, 1.8786,
        1.9584, 2.0021, 2.0230, 1.9706, 2.0015, 2.0618] 

print(len(numswithoutprefix))
# Out:
# 1023

# %%
plt.bar(np.array(range(len(numswithoutprefix))), numswithoutprefix) # 1024 PG19 ppl without prefix
# Out:
# <BarContainer object of 1023 artists>

# %%
numprefix = [ 4.4650,  4.2798,  1.2841,  2.7405,  2.3781, 10.0968,  2.5508,  0.7237,                                          
         6.0723,  4.2041,  3.0954,  2.8003,  2.6344,  2.8901,  3.3603,  3.0741,                                                             
         2.4374,  2.7995,  2.7851,  2.7291,  2.5734,  2.3001,  2.1078,  2.2665,                                                             
         2.2279,  1.8970,  1.7537,  1.6418,  1.5141,  1.6249,  1.5471,  1.5350,                                                             
         1.6702,  1.7184,  1.6762,  1.6729,  1.7094,  1.6918,  1.7347,  1.6259,                                                             
         1.6685,  1.4905,  1.6169,  1.5517,  1.5100,  1.4394,  1.5067,  1.5419,                                                             
         1.5604,  1.6313,  1.6078,  1.5479,  1.4479,  1.4894,  1.5883,  1.5756,                                                             
         1.5470,  1.5614,  1.5226,  1.5648,  1.5375,  1.5182,  1.5144,  1.5442,                                                             
         1.4926,  1.5015,  1.5524,  1.5740,  1.6032,  1.5277,  1.5655,  1.5990,                                                             
         1.5704,  1.5791,  1.6275,  1.5596,  1.6003,  1.6977,  1.5945,  1.5692,                                                             
         1.5834,  1.6887,  1.4960,  1.6136,  1.6021,  1.6342,  1.5740,  1.4821,                                                             
         1.5519,  1.6344,  1.6047,  1.5903,  1.5832,  1.6008,  1.7613,  1.6847,                                                             
         1.7164,  1.6216,  1.7546,  1.7086,  1.5998,  1.6169,  1.7241,  1.6781,                                                             
         1.6689,  1.6416,  1.7741,  1.6368,  1.6309,  1.7457,  1.7405,  1.7068,                                                             
         1.7153,  1.6634,  1.6388,  1.6508,  1.5981,  1.6345,  1.6258,  1.5725,                                                             
         1.7476,  1.6471,  1.6379,  1.6048,  1.6506,  1.7573,  1.6537,  1.5837,                                                             
         1.7009,  1.6365,  1.6618,  1.6817,  1.6697,  1.6246,  1.6279,  1.6383,                                                             
         1.6391,  1.6679,  1.6375,  1.7470,  1.6832,  1.6678,  1.6975,  1.7334,                                                             
         1.6265,  1.7036,  1.7064,  1.6662,  1.6885,  1.7015,  1.6771,  1.6904,                                                             
         1.6618,  1.6880,  1.6630,  1.6856,  1.7092,  1.7281,  1.6641,  1.6370,                                                             
         1.6363,  1.7327,  1.6781,  1.6766,  1.6412,  1.5889,  1.6114,  1.6904,                                                             
         1.8763,  1.9595,  1.8577,  1.8421,  1.9031,  1.8108,  1.8074,  1.8931,
         1.8224,  1.8401,  1.9089,  1.8810,  1.8979,  1.8916,  1.8587,  1.8119,
         1.8823,  1.7273,  1.9363,  1.8608,  1.8207,  1.8766,  1.8468,  1.9037,
         1.9586,  1.8304,  1.8102,  1.8603,  1.9054,  1.7762,  1.8354,  1.8548,
         1.9352,  1.8872,  1.8463,  1.8732,  1.9001,  1.9045,  1.8329,  1.7300,
         1.9089,  1.8818,  1.8617,  1.8739,  1.8164,  1.9275,  1.8578,  1.8173,
         1.8028,  1.8896,  1.8607,  1.8806,  1.9127,  1.8549,  1.8798,  1.8952,
         1.8979,  1.8655,  1.7697,  1.8906,  1.9135,  1.9534,  1.7955,  1.8733,
         1.8162,  1.9039,  1.8885,  1.9291,  1.8061,  1.8464,  1.9073,  1.8951,
         1.8433,  1.8411,  1.8976,  1.9716,  1.8174,  1.8390,  1.8505,  1.9345,
         1.9414,  1.9288,  1.8881,  1.8443,  1.8972,  1.8992,  1.7833,  1.9238,
         1.8686,  1.8552,  1.9024,  1.8189,  1.8695,  1.8215,  1.8091,  1.9256,
         1.8927,  2.0483,  1.8866,  1.8447,  1.9596,  1.8933,  1.9055]

# %%
plt.bar(np.array(range(len(numswithoutprefix))), numprefix) # 1024 PG19 ppl with prefix
# Out:
# <BarContainer object of 1023 artists>

# %%
plt.bar(np.array(range(len(numswithoutprefix))), numprefix) # 1024 PG19 ppl with prefix 
plt.ylim(0, 3.0)
# Out:
# (0.0, 3.0)

# %%
plain = [10.420,  8.409,  5.360,  5.066,  4.857,  4.589,  4.397,  4.196,  4.144,
         3.883,  3.858,  3.852,  3.750,  3.681,  3.621,  3.648,  3.513,  3.523,
         3.498,  3.499,  3.407,  3.363,  3.378,  3.331,  3.295,  3.269,  3.259,
         3.283,  3.245,  3.268,  3.188,  3.131,  3.118,  3.204,  3.206,  3.160,
         3.211,  3.226,  3.096,  3.110,  3.161,  3.055,  3.087,  3.088,  3.042,
         3.080,  3.098,  3.100,  3.078,  3.060,  3.038,  3.095,  3.017,  3.014,
         3.134,  3.038,  2.946,  3.045,  3.090,  3.059,  3.105,  3.077,  3.035,
         3.056,  2.967,  2.980,  3.042,  2.991,  2.940,  3.004,  2.983,  3.001,
         2.958,  2.978,  2.984,  2.978,  3.004,  3.093,  2.999,  2.985,  2.902,
         3.043,  2.987,  2.977,  3.009,  2.939,  2.927,  2.953,  2.906,  2.907,
         2.985,  2.931,  2.958,  2.951,  3.000,  2.946,  2.964,  2.923,  2.973,
         2.985,  2.960,  2.888,  2.879,  2.970,  2.883,  2.961,  2.895,  2.934,
         2.948,  2.996,  2.924,  2.965,  2.990,  2.910,  2.906,  2.912,  2.934,
         2.930,  2.971,  2.973,  2.880,  2.962,  2.883,  2.938,  2.918,  2.954,
         2.910,  2.896,  2.996,  2.934,  2.921,  2.953,  2.916,  2.927,  2.931,
         2.883,  2.926,  2.902,  2.920,  2.900,  2.891,  2.858,  2.950,  2.937,
         2.882,  2.881,  2.933,  2.930,  2.965,  2.953,  2.939,  2.944,  2.893,
         2.908,  2.977,  2.938,  2.899,  2.908,  2.903,  2.857,  2.914,  2.882,
         2.935,  2.968,  2.958,  2.917,  2.906,  2.940,  2.909,  2.918,  2.914,
         2.886,  2.907,  2.964,  2.878,  2.885,  2.877,  2.909,  2.927,  2.926,
         2.923,  2.930,  2.951,  2.846,  2.879,  2.868,  2.917,  2.881,  2.880,
         2.880,  2.853,  2.880,  2.835,  2.866,  2.884,  2.898,  2.800,  2.883,
         2.888,  2.826,  2.792,  2.851,  2.850,  2.793,  2.828,  2.873,  2.868,
         2.829,  2.806,  2.849,  2.859,  2.858,  2.811,  2.886,  2.755,  2.823,
         2.805,  2.805,  2.788,  2.770,  2.799,  2.758,  2.794,  2.715,  2.728,
         2.704,  2.737,  2.713,  2.768,  2.717,  2.719,  2.717,  2.731,  2.709,
         2.717,  2.673,  2.679,  2.728,  2.702,  2.689,  2.632,  2.740,  2.659,
         2.661,  2.685,  2.709,  2.703,  2.635,  2.637,  2.670,  2.672,  2.697,
         2.684,  2.677,  2.605,  2.644,  2.650,  2.433,  1.962] 

indices = np.arange(1, len(plain) + 1) 
plt.bar(indices, plain)
# Out:
# <BarContainer object of 259 artists>

# %%
indices = np.arange(len(plain))

# %%
interl = [10.330,  5.125,  3.910,  3.766,  3.694,  3.610,  3.532,  2.908,  3.020,
         2.931,  2.962,  3.049,  3.028,  3.014,  2.683,  2.777,  2.753,  2.840,
         2.874,  2.940,  2.880,  2.587,  2.646,  2.713,  2.737,  2.753,  2.774,
         2.842,  2.580,  2.628,  2.659,  2.663,  2.677,  2.764,  2.827,  2.505,
         2.621,  2.722,  2.630,  2.640,  2.762,  2.711,  2.531,  2.586,  2.601,
         2.654,  2.703,  2.757,  2.755,  2.486,  2.562,  2.652,  2.600,  2.681,
         2.790,  2.765,  2.477,  2.590,  2.638,  2.659,  2.766,  2.778,  2.761,
         2.553,  2.572,  2.603,  2.701,  2.687,  2.669,  2.754,  2.530,  2.590,
         2.580,  2.669,  2.671,  2.723,  2.770,  2.629,  2.582,  2.658,  2.595,
         2.759,  2.743,  2.773,  2.588,  2.548,  2.578,  2.666,  2.660,  2.681,
         2.790,  2.526,  2.575,  2.613,  2.704,  2.714,  2.757,  2.724,  2.579,
         2.629,  2.666,  2.638,  2.665,  2.755,  2.725,  2.575,  2.552,  2.645,
         2.673,  2.732,  2.726,  2.786,  2.605,  2.580,  2.625,  2.684,  2.694,
         2.745,  2.800,  2.602,  2.527,  2.680,  2.658,  2.736,  2.732,  2.796,
         2.566,  2.545,  2.722,  2.686,  2.702,  2.741,  2.748,  2.578,  2.621,
         2.607,  2.720,  2.723,  2.772,  2.734,  2.543,  2.542,  2.701,  2.720,
         2.706,  2.691,  2.783,  2.592,  2.644,  2.707,  2.729,  2.751,  2.710,
         2.771,  2.612,  2.638,  2.656,  2.714,  2.734,  2.716,  2.788,  2.567,
         2.524,  2.485,  2.497,  2.554,  2.476,  2.308,  2.495,  2.478,  2.529,
         2.459,  2.483,  2.558,  2.387,  2.499,  2.491,  2.552,  2.406,  2.505,
         2.554,  2.348,  2.450,  2.479,  2.489,  2.494,  2.485,  2.479,  2.275,
         2.430,  2.455,  2.414,  2.496,  2.450,  2.502,  2.350,  2.465,  2.470,
         2.466,  2.469,  2.426,  2.498,  2.287,  2.389,  2.382,  2.561,  2.460,
         2.416,  2.486,  2.379,  2.475,  2.385,  2.409,  2.491,  2.457,  2.507,
         2.333,  2.411,  2.465,  2.488,  2.527,  2.260,  1.672]

# %%
plt.bar(indices, plain) 
plt.bar(indices, interl)
# Out:
# <BarContainer object of 259 artists>

# %% [markdown]
# 1. Where does the information come from (second-to-last)
# 2. How to inject (modulation)

# %%
plt.bar(indices[-100 : ], plain[-100 : ]) 
plt.bar(indices[-100 : ], interl[-100 : ]) 
plt.ylim(2, 3)
# Out:
# (2.0, 3.0)

# %%
llama27blist = [10.330,  5.036,  3.851,  3.726,  3.660,  3.591,  3.519,  2.823,  2.817,
         2.761,  2.809,  2.911,  2.914,  2.934,  2.754,  2.618,  2.614,  2.695,
         2.751,  2.833,  2.797,  2.682,  2.529,  2.567,  2.604,  2.633,  2.668,
         2.751,  2.681,  2.515,  2.536,  2.536,  2.566,  2.661,  2.750,  2.653,
         2.501,  2.596,  2.513,  2.522,  2.669,  2.628,  2.653,  2.462,  2.466,
         2.537,  2.594,  2.663,  2.670,  2.616,  2.441,  2.512,  2.478,  2.588,
         2.696,  2.676,  2.607,  2.471,  2.501,  2.530,  2.658,  2.665,  2.674,
         2.681,  2.453,  2.464,  2.554,  2.565,  2.551,  2.642,  2.642,  2.454,
         2.424,  2.501,  2.532,  2.596,  2.656,  2.712,  2.439,  2.484,  2.431,
         2.602,  2.608,  2.648,  2.657,  2.390,  2.404,  2.485,  2.494,  2.525,
         2.645,  2.587,  2.395,  2.426,  2.504,  2.527,  2.585,  2.564,  2.645,
         2.451,  2.454,  2.440,  2.476,  2.566,  2.558,  2.626,  2.368,  2.439,
         2.467,  2.530,  2.534,  2.599,  2.648,  2.386,  2.409,  2.455,  2.482,
         2.537,  2.610,  2.638,  2.322,  2.446,  2.434,  2.513,  2.516,  2.590,
         2.662,  2.344,  2.481,  2.454,  2.470,  2.524,  2.538,  2.619,  2.416,
         2.379,  2.474,  2.482,  2.540,  2.517,  2.582,  2.350,  2.447,  2.459,
         2.467,  2.466,  2.560,  2.613,  2.408,  2.447,  2.462,  2.492,  2.471,
         2.539,  2.631,  2.407,  2.389,  2.447,  2.476,  2.471,  2.553,  2.571,
         2.412,  2.420,  2.477,  2.468,  2.476,  2.544,  2.569,  2.363,  2.416,
         2.421,  2.438,  2.521,  2.496,  2.587,  2.336,  2.406,  2.440,  2.456,
         2.482,  2.525,  2.634,  2.316,  2.384,  2.434,  2.462,  2.489,  2.529,
         2.579,  2.343,  2.389,  2.378,  2.408,  2.478,  2.514,  2.503,  2.368,
         2.387,  2.389,  2.373,  2.481,  2.487,  2.515,  2.329,  2.394,  2.422,
         2.423,  2.417,  2.493,  2.559,  2.378,  2.377,  2.443,  2.366,  2.481,
         2.478,  2.532,  2.325,  2.339,  2.381,  2.387,  2.458,  2.403,  2.517,
         2.284,  2.327,  2.344,  2.422,  2.418,  2.451,  2.496,  2.291,  2.324,
         2.337,  2.344,  2.381,  2.439,  2.509,  2.269,  2.252,  2.395,  2.361,
         2.386,  2.451,  2.513,  2.296,  2.270,  2.317,  2.373,  2.415,  2.491,
         2.527,  2.282,  2.254,  2.339,  2.362,  2.169,  1.615] 

plt.bar(indices, llama27blist)
# Out:
# <BarContainer object of 259 artists>

# %%
# tinyllama1blist = [10.330,  5.125,  3.910,  3.766,  3.694,  3.610,  3.532,  2.908,  3.020,
#          2.931,  2.962,  3.049,  3.028,  3.014,  2.683,  2.777,  2.753,  2.840,
#          2.874,  2.940,  2.880,  2.587,  2.646,  2.713,  2.737,  2.753,  2.774,
#          2.842,  2.580,  2.628,  2.659,  2.663,  2.677,  2.764,  2.827,  2.505,
#          2.621,  2.722,  2.630,  2.640,  2.762,  2.711,  2.531,  2.586,  2.601,
#          2.654,  2.703,  2.757,  2.755,  2.486,  2.562,  2.652,  2.600,  2.681,
#          2.790,  2.765,  2.477,  2.590,  2.638,  2.659,  2.766,  2.778,  2.761,
#          2.553,  2.572,  2.603,  2.701,  2.687,  2.669,  2.754,  2.530,  2.590,
#          2.580,  2.669,  2.671,  2.723,  2.770,  2.629,  2.582,  2.658,  2.595,
#          2.759,  2.743,  2.773,  2.588,  2.548,  2.578,  2.666,  2.660,  2.681,
#          2.790,  2.526,  2.575,  2.613,  2.704,  2.714,  2.757,  2.724,  2.579,
#          2.629,  2.666,  2.638,  2.665,  2.755,  2.725,  2.575,  2.552,  2.645,
#          2.673,  2.732,  2.726,  2.786,  2.605,  2.580,  2.625,  2.684,  2.694,
#          2.745,  2.800,  2.602,  2.527,  2.680,  2.658,  2.736,  2.732,  2.796,
#          2.566,  2.545,  2.722,  2.686,  2.702,  2.741,  2.748,  2.578,  2.621,
#          2.607,  2.720,  2.723,  2.772,  2.734,  2.543,  2.542,  2.701,  2.720,
#          2.706,  2.691,  2.783,  2.592,  2.644,  2.707,  2.729,  2.751,  2.710,
#          2.771,  2.612,  2.638,  2.656,  2.714,  2.734,  2.716,  2.788,  2.567,
#          2.658,  2.707,  2.762,  2.740,  2.756,  2.821,  2.578,  2.622,  2.698,
#          2.695,  2.732,  2.798,  2.767,  2.609,  2.593,  2.696,  2.735,  2.748,
#          2.779,  2.800,  2.652,  2.607,  2.679,  2.732,  2.768,  2.791,  2.813,
#          2.624,  2.617,  2.697,  2.687,  2.719,  2.776,  2.812,  2.559,  2.661,
#          2.702,  2.707,  2.676,  2.789,  2.797,  2.567,  2.629,  2.701,  2.749,
#          2.744,  2.740,  2.821,  2.632,  2.664,  2.682,  2.776,  2.678,  2.776,
#          2.784,  2.573,  2.613,  2.652,  2.696,  2.710,  2.778,  2.706,  2.572,
         2.740,  2.815,  2.693,  2.674,  2.762,  2.666,  2.576,  2.675,  2.651,
         2.668,  2.730,  2.701,  2.733,  2.536,  2.697,  2.676,  2.584,  2.688,
         2.752,  2.674,  2.463,  2.585,  2.624,  2.709,  2.690,  2.704,  2.685,
         2.569,  2.574,  2.659,  2.694,  2.692,  2.630,  2.617,  2.511,  2.641,
         2.606,  2.659,  2.664,  2.682,  2.699,  2.597,  2.598,  2.641,  2.556,
         2.757,  2.721,  2.674,  2.503,  2.513,  2.621,  2.628,  2.597,  2.567,
         2.727,  2.421,  2.572,  2.643,  2.623,  2.679,  2.662,  2.556,  2.464,
         2.581,  2.663,  2.592,  2.578,  2.601,  2.509,  2.507,  2.571,  2.628,
         2.594,  2.655,  2.577,  2.639,  2.502,  2.502,  2.576,  2.587,  2.570,
         2.591,  2.715,  2.507,  2.432,  2.614,  2.539,  2.659,  2.622,  2.639,
         2.475,  2.516,  2.674,  2.556,  2.529,  2.551,  2.671,  2.396,  2.556,
         2.513,  2.578,  2.616,  2.676,  2.553,  2.357,  2.489,  2.523,  2.625,
         2.571,  2.552,  2.598,  2.433,  2.600,  2.658,  2.559,  2.623,  2.560,
         2.574,  2.467,  2.548,  2.602,  2.576,  2.548,  2.552,  2.555,  2.372,
         2.572,  2.609,  2.571,  2.565,  2.563,  2.572,  2.426,  2.528,  2.569,
         2.543,  2.516,  2.602,  2.549,  2.382,  2.480,  2.559,  2.535,  2.562,
         2.551,  2.577,  2.527,  2.421,  2.524,  2.569,  2.586,  2.516,  2.543,
         2.399,  2.463,  2.494,  2.523,  2.521,  2.536,  2.526,  2.356,  2.537,
         2.524,  2.485,  2.497,  2.554,  2.476,  2.308,  2.495,  2.478,  2.529,
         2.459,  2.483,  2.558,  2.387,  2.499,  2.491,  2.552,  2.406,  2.505,
         2.554,  2.348,  2.450,  2.479,  2.489,  2.494,  2.485,  2.479,  2.275,
         2.430,  2.455,  2.414,  2.496,  2.450,  2.502,  2.350,  2.465,  2.470,
         2.466,  2.469,  2.426,  2.498,  2.287,  2.389,  2.382,  2.561,  2.460,
         2.416,  2.486,  2.379,  2.475,  2.385,  2.409,  2.491,  2.457,  2.507,
         2.333,  2.411,  2.465,  2.488,  2.527,  2.260,  1.672]

# %%
import torch 
from transformers import AutoTokenizer 

tokenizer1 = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf") 
outputidstensor = torch.tensor([    2,     2,   894, 29901,  7908, 29891,   338,  3907,  1869, 15713,
          363, 17803,   411,   670,  3023,  7875, 29892, 29420, 29892, 16866,
         2350,   295, 29892,   319,  5022, 29892,   322,   476,  1794, 29889,
          940,  4225,   304,  1073,   920,  1784, 12785,   304,  5700,   278,
         1869, 15713,   964,   304,  9080,   372, 29889,  7908, 29891,   871,
        10753,   697,  8424, 29889,   319,  5022,  1838, 29915, 29873,   763,
         1869, 15713,  1568,   322,   674,  3117,   871, 17545,  7171,   506,
        18423,   322,  4497,   328, 29889,   476,  1794,   338,  2337,  9074,
        14793,   322,   674, 17545,  8951,   408,  1568,   408,  7908, 29891,
